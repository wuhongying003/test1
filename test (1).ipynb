# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## wuhongying
# software testing engineer

# %% [markdown]
# ##### I am interested in data science because I am interested in data

# %% [markdown]
# ### Calculate the result of one plus one in Cell 5

# %%
1+1
# Out:
# 2

# %% [markdown]
# ### wewewew
# ertetr
# 675765756
# 67876876gh
# 5654564
# 567567
# 87987
# 76876
